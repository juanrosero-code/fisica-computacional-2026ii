# %% [markdown]
# #Altura Máxima de un Proyectil (Fortran) - Juan Manuel Rosero García

# %%
#Agrego Fortran al Colab
# !apt-get -qq install gfortran
# !gfortran --version
# Out:
# GNU Fortran (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile hmaxima.f90
#
# program hmaxima
#
#     implicit none
#       ! Defino variables y parámetros
#
#     real :: v0, angulo_rad, angulo_grados, h_max, g
#     real, parameter :: pi = 3.14159265
#
#       ! Valor de la gravedad
#     g = 9.8
#
#       ! Tomo los datos iniciales
#     print *, "Ingrese la velocidad inicial (m/s):"
#     read *, v0
#
#     print *, "Ingrese el angulo de lanzamiento (grados):"
#     read *, angulo_grados
#
#     ! Cálculo de la altura máxima
#
#     angulo_rad = angulo_grados * pi / 180.0
#     h_max = (v0**2 * sin(angulo_rad)**2) / (2*g)
#
#       ! Muestra de resultados
#     print *, "La altura maxima es:", h_max, "metros"
#
# end program hmaxima
# Out:
# Overwriting hmaxima.f90

# %%
# !gfortran hmaxima.f90 -o hmaxima

# %%
# !./hmaxima
# Out:
#  Ingrese la velocidad inicial (m/s):
# 9.8
#  Ingrese el angulo de lanzamiento (grados):
# 90
#  La altura maxima es:   4.90000010     metros
